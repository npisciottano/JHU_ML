# %%
print("Hello World")
# Out:
# Hello World

# %%
s = 3
t = 2
s*t
# Out:
# 6

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([3,2,5], [1,2,3])

# %%
plt.scatter([3,2,5], [1,2,3])
